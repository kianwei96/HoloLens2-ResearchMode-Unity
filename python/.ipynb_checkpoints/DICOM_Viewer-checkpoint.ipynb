# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os
import glob
import pydicom

# %% [markdown]
# # accumulate diff

# %%
file_list = glob.glob("data/dicom_sample/*")
for idx, file in enumerate(file_list):

    data = pydicom.dcmread(file)
    img = data.pixel_array[:,:,0]
    
    if idx == 0:
        accumulator = np.zeros(img.shape) 
    else:
        accumulator += np.abs(img - storage_image)/255
    storage_image = img.copy()
    
    img = cv2.resize(img, (int(img.shape[1]/2), int(img.shape[0]/2)))
    cv2.imshow('test', img)
    
    key = cv2.waitKey(10)
    if key == ord('q'):
        break 
        
cv2.destroyAllWindows()

# %%
mask_candidate1 = cv2.dilate((accumulator < len(file_list)/5).astype(np.uint8), np.ones((3,3), 'uint8'), iterations=3)

# %%
file_list = glob.glob("data/dicom_sample/*")
for idx, file in enumerate(file_list):

    data = pydicom.dcmread(file)
    img = data.pixel_array[:,:,0]
    img[np.where(mask_candidate1)] = 0
    
    img = cv2.resize(img, (int(img.shape[1]/2), int(img.shape[0]/2)))
    cv2.imshow('test', img)
    
    key = cv2.waitKey(10)
    if key == ord('q'):
        break 
        
cv2.destroyAllWindows()

# %% [markdown]
# # accumulate whites

# %%
file_list = glob.glob("data/dicom_sample/*")
for idx, file in enumerate(file_list):

    data = pydicom.dcmread(file)
    img = data.pixel_array[:,:,0]
    
    if idx == 0:
        accumulator = np.zeros(img.shape) 
    else:
        accumulator += img > 150
    
    img = cv2.resize(img, (int(img.shape[1]/2), int(img.shape[0]/2)))
    cv2.imshow('test', img)
    
    key = cv2.waitKey(10)
    if key == ord('q'):
        break 
        
cv2.destroyAllWindows()

# %%
mask_candidate2 = cv2.dilate((accumulator > len(file_list)/2).astype(np.uint8), np.ones((3,3), 'uint8'), iterations=3)

# %%
file_list = glob.glob("data/dicom_sample/*")
for idx, file in enumerate(file_list):

    data = pydicom.dcmread(file)
    img = data.pixel_array[:,:,0]
    img[np.where(mask_candidate2)] = 0
    
    img = cv2.resize(img, (int(img.shape[1]/2), int(img.shape[0]/2)))
    cv2.imshow('test', img)
    
    key = cv2.waitKey(10)
    if key == ord('q'):
        break 
        
cv2.destroyAllWindows()

# %%
mc = np.load('55mm.npy')
plt.imshow(mc)

# %%
data = pydicom.dcmread(glob.glob("data/dicom_sample/*")[100])
image = data.pixel_array[:,:,0]
dX = data[0x0018,0x6011][0][0x0018, 0x602c].value
dY = data[0x0018,0x6011][0][0x0018, 0x602e].value

# %%
CamIntMat = np.eye(3) * [dX,dY,1]
CamIntMat
# Out:
# array([[0.003393, 0.      , 0.      ],
#        [0.      , 0.003393, 0.      ],
#        [0.      , 0.      , 1.      ]])

# %%
Ys, Xs = np.meshgrid(range(image.shape[0]), range(image.shape[1]), indexing='ij')
print(Ys.shape, Xs.shape, image.shape)
# Out:
# (1647, 1128) (1647, 1128) (1647, 1128)

# %%
Ys = Ys.reshape((-1,1))
Xs = Xs.reshape((-1,1))
mc = mc.reshape((-1,1))
image_coords = np.hstack((np.hstack((Xs, Ys)), np.ones(Xs.shape[0])[:,None])).transpose()
image_coords = CamIntMat.dot(image_coords)[:-1,:]
image1 = image.reshape((-1,1))
print(mc.shape, Ys.shape, Xs.shape, image1.shape)
# Out:
# (1857816, 1) (1857816, 1) (1857816, 1) (1857816, 1)

# %%
image_coords.shape
# Out:
# (2, 1857816)

# %%
plt.scatter(image_coords[0,::10], image_coords[1,::10], c=image1[::10])
plt.gca().invert_yaxis()

# %%
plt.rcParams['figure.figsize'] = [20, 10]
channel = 0

for idx, file in enumerate(glob.glob("data/dicom_sample/*")):
    print('\nfile: ', file)
    data = pydicom.dcmread(file)
    print(
      data.pixel_array.shape, data.DepthOfScanField, data.InstanceNumber, data.NumberOfFrames, 
      data.RescaleSlope, data.RescaleIntercept, data.SamplesPerPixel
     )
    print(data.SeriesDate, data.SeriesInstanceUID)
    dX = data[0x0018,0x6011][0][0x0018, 0x602c].value
    dY = data[0x0018,0x6011][0][0x0018, 0x602e].value
    print(dX, dY, data.ContentTime, np.min(data.pixel_array[:,:,channel]), np.max(data.pixel_array[:,:,channel]))

    plt.subplot(2,5,idx+1)
    plt.imshow(data.pixel_array[:,:,channel])
# Out:
# file:  data/dicom_sample\20220131095609.dcm
# (1647, 1128, 3) 55 1 1 1 0 3
# 20220131 1.2.276.0.7230010.3.1.3.0.3981.1643594169.434872
# 0.003393 0.003393 095503 0 255
#
# file:  data/dicom_sample\20220131095612.dcm
# (1647, 1128, 3) 55 1 1 1 0 3
# 20220131 1.2.276.0.7230010.3.1.3.0.3981.1643594172.434875
# 0.003393 0.003393 095504 0 255
#
# file:  data/dicom_sample\20220131095619.dcm
# (1647, 1128, 3) 55 1 1 1 0 3
# 20220131 1.2.276.0.7230010.3.1.3.0.3981.1643594179.434878
# 0.003393 0.003393 095504 0 255
#
# file:  data/dicom_sample\20220131095624.dcm
# (1647, 1128, 3) 55 1 1 1 0 3
# 20220131 1.2.276.0.7230010.3.1.3.0.3981.1643594184.434881
# 0.003393 0.003393 095504 0 255
#
# file:  data/dicom_sample\20220131095628.dcm
# (1647, 1128, 3) 55 1 1 1 0 3
# 20220131 1.2.276.0.7230010.3.1.3.0.3981.1643594188.434884
# 0.003393 0.003393 095504 0 255
#
# file:  data/dicom_sample\20220131095631.dcm
# (1647, 1128, 3) 55 1 1 1 0 3
# 20220131 1.2.276.0.7230010.3.1.3.0.3981.1643594191.434887
# 0.003393 0.003393 095504 0 255
#
# file:  data/dicom_sample\20220131095635.dcm
# (1647, 1128, 3) 55 1 1 1 0 3
# 20220131 1.2.276.0.7230010.3.1.3.0.3981.1643594195.434890
# 0.003393 0.003393 095504 0 255
#
# file:  data/dicom_sample\20220131095638.dcm
# (1647, 1128, 3) 55 1 1 1 0 3
# 20220131 1.2.276.0.7230010.3.1.3.0.3981.1643594198.434893
# 0.003393 0.003393 095504 0 255
#
# file:  data/dicom_sample\20220131095641.dcm
# (1647, 1128, 3) 55 1 1 1 0 3
# 20220131 1.2.276.0.7230010.3.1.3.0.3981.1643594201.434896
# 0.003393 0.003393 095505 0 255
#
# file:  data/dicom_sample\20220131095645.dcm
# (1647, 1128, 3) 55 1 1 1 0 3
# 20220131 1.2.276.0.7230010.3.1.3.0.3981.1643594205.434899
# 0.003393 0.003393 095505 0 255
#
# file:  data/dicom_sample\20220131095648.dcm
# (1647, 1128, 3) 55 1 1 1 0 3
# 20220131 1.2.276.0.7230010.3.1.3.0.3981.1643594208.434902
# 0.003393 0.003393 095505 0 255
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-180-48fde0e6046d> in <module>
#      14     print(dX, dY, data.ContentTime, np.min(data.pixel_array[:,:,channel]), np.max(data.pixel_array[:,:,channel]))
#      15
# ---> 16     plt.subplot(2,5,idx+1)
#      17     plt.imshow(data.pixel_array[:,:,channel])
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1266
#    1267     # First, search for an existing subplot with a matching spec.
# -> 1268     key = SubplotSpec._from_subplot_args(fig, args)
#    1269
#    1270     for ax in fig.axes:
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\gridspec.py in _from_subplot_args(figure, args)
#     606         else:
#     607             if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 608                 raise ValueError(
#     609                     f"num must be 1 <= num <= {rows*cols}, not {num!r}")
#     610             i = j = num
#
# ValueError: num must be 1 <= num <= 10, not 11

# %%
data1 = pydicom.dcmread(glob.glob("data/dicom_sample/*")[0])
data2 = pydicom.dcmread(glob.glob("data/dicom_sample/*")[1])

# %%
data1
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 196
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Ultrasound Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.276.0.7230010.3.1.4.0.3027.1643545697.169777
# (0002, 0010) Transfer Syntax UID                 UI: JPEG Baseline (Process 1)
# (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7230010.3.0.3.6.4
# (0002, 0013) Implementation Version Name         SH: 'OFFIS_DCMTK_364'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 192'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# (0008, 0016) SOP Class UID                       UI: Ultrasound Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7230010.3.1.4.0.3027.1643545697.169777
# (0008, 0020) Study Date                          DA: '20220130'
# (0008, 0021) Series Date                         DA: '20220130'
# (0008, 0023) Content Date                        DA: '20220130'
# (0008, 0030) Study Time                          TM: '202817'
# (0008, 0031) Series Time                         TM: '202817'
# (0008, 0033) Content Time                        TM: '202800'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'US'
# (0008, 0070) Manufacturer                        LO: 'Sonostar'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: ''
# (0008, 1090) Manufacturer's Model Name           LO: 'SL-2C'
# (0010, 0010) Patient's Name                      PN: '--'
# (0010, 0020) Patient ID                          LO: '--'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0018, 0015) Body Part Examined                  CS: ''
# (0018, 1000) Device Serial Number                LO: 'SL-2C GMBHKA097'
# (0018, 1020) Software Versions                   LO: 'WirelessUSG3.6.6'
# (0018, 5050) Depth of Scan Field                 IS: '55'
# (0018, 6011)  Sequence of Ultrasound Regions  1 item(s) ----
#    (0018, 6012) Region Spatial Format               US: 1
#    (0018, 6014) Region Data Type                    US: 1
#    (0018, 6016) Region Flags                        UL: 2
#    (0018, 6018) Region Location Min X0              UL: 0
#    (0018, 601a) Region Location Min Y0              UL: 0
#    (0018, 601c) Region Location Max X1              UL: 1128
#    (0018, 601e) Region Location Max Y1              UL: 1647
#    (0018, 6020) Reference Pixel X0                  SL: 0
#    (0018, 6022) Reference Pixel Y0                  SL: 0
#    (0018, 6024) Physical Units X Direction          US: 3
#    (0018, 6026) Physical Units Y Direction          US: 3
#    (0018, 6028) Reference Pixel Physical Value X    FD: 0.0
#    (0018, 602a) Reference Pixel Physical Value Y    FD: 0.0
#    (0018, 602c) Physical Delta X                    FD: 0.003393
#    (0018, 602e) Physical Delta Y                    FD: 0.003393
#    (0018, 6030) Transducer Frequency                UL: 7500
#    ---------
# (0018, 6031) Transducer Type                     CS: 'CURVED LINEAR'
# (0020, 000d) Study Instance UID                  UI: 1.2.276.0.7230010.3.1.2.0.3027.1643545697.169775
# (0020, 000e) Series Instance UID                 UI: 1.2.276.0.7230010.3.1.3.0.3027.1643545697.169776
# (0020, 0013) Instance Number                     IS: '1'
# (0028, 0002) Samples per Pixel                   US: 3
# (0028, 0004) Photometric Interpretation          CS: 'RGB'
# (0028, 0006) Planar Configuration                US: 0
# (0028, 0008) Number of Frames                    IS: '1'
# (0028, 0010) Rows                                US: 1647
# (0028, 0011) Columns                             US: 1128
# (0028, 0014) Ultrasound Color Data Present       US: 1
# (0028, 0100) Bits Allocated                      US: 8
# (0028, 0101) Bits Stored                         US: 8
# (0028, 0102) High Bit                            US: 7
# (0028, 0103) Pixel Representation                US: 0
# (0028, 1052) Rescale Intercept                   DS: '0.0'
# (0028, 1053) Rescale Slope                       DS: '1.0'
# (0032, 1033) Requesting Service                  LO: ''
# (7fe0, 0010) Pixel Data                          OB: Array of 355744 elements

# %%
1647 * 0.003393
# Out:
# 5.588271000000001

# %%
plt.imshow(data1.pixel_array[50:150,300:400,0])

# %%
while True:
    img = data.pixel_array
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cv2.imshow('test', img[:,:,2])
    key = cv2.waitKey(1)
    if key == ord('q'):
        break  
cv2.destroyAllWindows()

# %%
data.pixel_array.shape
# Out:
# (1647, 1128, 3)

# %%
px_flat = data.pixel_array.reshape(-1, 3)
np.max(px_flat, axis=0)
# Out:
# array([255, 129, 130], dtype=uint8)

# %%
plt.plot(px_flat[:,2], 'x')
